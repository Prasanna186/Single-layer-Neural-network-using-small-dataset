# %%
import sklearn
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("/content/Single Layer Perceptron Dataset.csv")

# %%
data
# Out:
#     Pattern  Feature1  Feature2  Feature3  Class_Label
# 0         1         1      0.08      0.72            1
# 1         2         1      0.10      1.00            1
# 2         3         1      0.26      0.58            1
# 3         4         1      0.35      0.95            0
# 4         5         1      0.45      0.15            1
# 5         6         1      0.60      0.30            1
# 6         7         1      0.70      0.65            0
# 7         8         1      0.92      0.45            0
# 8         9         1      0.42      0.85            0
# 9        10         1      0.65      0.55            0
# 10       11         1      0.20      0.30            1
# 11       12         1      0.20      1.00            0
# 12       13         1      0.85      0.10            1

# %%
x = data.iloc[:,:-1].values
y = data.iloc[:,-1].values

# %%
x
# Out:
# array([[ 1.  ,  1.  ,  0.08,  0.72],
#        [ 2.  ,  1.  ,  0.1 ,  1.  ],
#        [ 3.  ,  1.  ,  0.26,  0.58],
#        [ 4.  ,  1.  ,  0.35,  0.95],
#        [ 5.  ,  1.  ,  0.45,  0.15],
#        [ 6.  ,  1.  ,  0.6 ,  0.3 ],
#        [ 7.  ,  1.  ,  0.7 ,  0.65],
#        [ 8.  ,  1.  ,  0.92,  0.45],
#        [ 9.  ,  1.  ,  0.42,  0.85],
#        [10.  ,  1.  ,  0.65,  0.55],
#        [11.  ,  1.  ,  0.2 ,  0.3 ],
#        [12.  ,  1.  ,  0.2 ,  1.  ],
#        [13.  ,  1.  ,  0.85,  0.1 ]])

# %%
y
# Out:
# array([1, 1, 1, 0, 1, 1, 0, 0, 0, 0, 1, 0, 1])

# %%
plt.scatter(x[y==0,0],x[y==0,1])
plt.scatter(x[y==1,0],x[y==1,1])
plt.show()

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (10, 4)
# (3, 4)
# (10,)
# (3,)

# %%
def sigmoid(x):
  return 1/(1+np.exp(-x))

# %%
n_hidden = 5
n_epochs = 100
learning_rate = 1

# %%
weights_hidden = np.random.normal(size=(x_train.shape[1],n_hidden))
weights_output = np.random.normal(size=(n_hidden,1))

# %%
hist_loss = []
hist_accuracy = []
print(weights_hidden)
print(weights_output)
# Out:
# [[ 0.3418245   0.3267608   0.35831452 -0.0987203  -0.22929517]
#  [-1.17505503  0.74831854 -0.21806999 -0.0999316  -0.50691449]
#  [-0.10789753 -0.64719283 -0.62689563 -0.0232853  -1.9929882 ]
#  [-0.90577218  0.60627595 -1.1674954  -2.01476796  0.08679568]]
# [[-1.24223174]
#  [-0.45945914]
#  [-0.71439731]
#  [ 0.98693477]
#  [-1.24532289]]
